# %%
#Bai tap quan ly sach

class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def display_info(self):
        print(f"Tên sách: {self.title}")
        print(f"Tác giả: {self.author}")
        print(f"Năm xuất bản: {self.year}")
        print("------------------------")


book1 = Book("Dế Mèn Phiêu Lưu Ký", "Tô Hoài", 1941)
book2 = Book("Lập Trình Python Cơ Bản", "Nguyễn Văn A", 2022)


book1.display_info()
book2.display_info()
# Out:
# Tên sách: Dế Mèn Phiêu Lưu Ký
# Tác giả: Tô Hoài
# Năm xuất bản: 1941
# ------------------------
# Tên sách: Lập Trình Python Cơ Bản
# Tác giả: Nguyễn Văn A
# Năm xuất bản: 2022
# ------------------------

# %%
#Bai toan tai khoan ngan hang
class BankAccount:
    def __init__(self, account_number):
        self._account_number = account_number
        self._balance = 0

    @property
    def account_number(self):
        return self._account_number

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Nạp {amount} thành công")
        else:
            print("Số tiền nạp không hợp lệ")

    def withdraw(self, amount):
        if amount <= 0:
            print("Số tiền rút không hợp lệ")
        elif amount > self._balance:
            print("Không đủ số dư để rút")
        else:
            self._balance -= amount
            print(f"Rút {amount} thành công")

    def get_balance(self):
        return self._balance


account = BankAccount("123456789")

print("Số tài khoản:", account.account_number)

account.deposit(1000)
account.withdraw(300)
account.withdraw(800)

print("Số dư hiện tại:", account.get_balance())
# Out:
# Số tài khoản: 123456789
# Nạp 1000 thành công
# Rút 300 thành công
# Không đủ số dư để rút
# Số dư hiện tại: 700

# %%
#Bai tap ke thua 
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        print(f"Tên: {self.name}")
        print(f"Tuổi: {self.age}")


class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def study(self):
        print(f"{self.name} đang học bài...")

    def display_info(self):
        super().display_info()
        print(f"Mã sinh viên: {self.student_id}")
        print("------------------------")


student1 = Student("Nguyễn Văn B", 20, "SV001")

student1.display_info()
student1.study()
# Out:
# Tên: Nguyễn Văn B
# Tuổi: 20
# Mã sinh viên: SV001
# ------------------------
# Nguyễn Văn B đang học bài...

# %%
#Bai phuong tien giao thong 
class Vehicle:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        print(f"Hãng: {self.brand}")
        print(f"Mẫu: {self.model}")
        print(f"Năm sản xuất: {self.year}")


class Car(Vehicle):
    def __init__(self, brand, model, year, num_doors):
        super().__init__(brand, model, year)
        self.num_doors = num_doors

    def display_info(self):
        super().display_info()
        print(f"Số cửa: {self.num_doors}")
        print("------------------------")


class Bike(Vehicle):
    def __init__(self, brand, model, year, bike_type):
        super().__init__(brand, model, year)
        self.type = bike_type

    def display_info(self):
        super().display_info()
        print(f"Loại xe: {self.type}")
        print("------------------------")


car1 = Car("Toyota", "Camry", 2022, 4)
bike1 = Bike("Giant", "ATX", 2021, "Mountain")

car1.display_info()
bike1.display_info()
# Out:
# Hãng: Toyota
# Mẫu: Camry
# Năm sản xuất: 2022
# Số cửa: 4
# ------------------------
# Hãng: Giant
# Mẫu: ATX
# Năm sản xuất: 2021
# Loại xe: Mountain
# ------------------------

# %%
#Bai tap matpolib
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.plot(x, y)

plt.title("Do thi y = x^2")
plt.xlabel("Truc X")
plt.ylabel("Truc Y")

plt.show()

# %%
#List Comprehension 
numbers = [x for x in range(1, 101) if x % 3 == 0 and x % 5 == 0]

print(numbers)
# Out:
# [15, 30, 45, 60, 75, 90]

# %%
#Bai tap Generator + next()
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True


prime_gen = (x for x in range(1, 21) if is_prime(x))


while True:
    try:
        print(next(prime_gen))
    except StopIteration:
        break
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19
